# %%
# !pip install matplotlib seaborn pandas numpy sqlalchemy pymysql cryptography

# %%
import pandas as pd
import numpy as np

# %%
# Loading the data
df = pd.read_csv('customer_purchase_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Loading the data
# ----> 2 df = pd.read_csv('customer_purchase_data.csv')
#
# File c:\Users\alokd\miniconda3\envs\behaviour_analysis\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Short preview
df.head()
# Out:
#    Customer_ID  Age  Gender Item_Purchased     Category  Purchase_Amount  \
# 0            1   43    Male         Gloves  Accessories               63
# 1            2   63  Female          Jeans     Clothing               78
# 2            3   30  Female       Backpack  Accessories               28
# 3            4   24    Male          Boots     Footwear               74
# 4            5   33  Female         Jacket    Outerwear               69
#
#        Location Size           Color  Season  Review_Rating  \
# 0  South Dakota    S  DarkOliveGreen  Summer            3.2
# 1        Alaska    L     LightSalmon    Fall            4.1
# 2        Kansas    S           Ivory  Summer            4.3
# 3       Florida    L       DarkKhaki    Fall            2.9
# 4          Utah    S     YellowGreen  Winter            3.1
#
#   Subscription_Status Shipping_Type Discount_Applied  Previous_Purchases  \
# 0                 Yes  Store Pickup               No                  70
# ...

# %%
# Basic Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_ID             15000 non-null  int64
#  1   Age                     15000 non-null  int64
#  2   Gender                  15000 non-null  object
#  3   Item_Purchased          15000 non-null  object
#  4   Category                15000 non-null  object
#  5   Purchase_Amount         15000 non-null  int64
#  6   Location                15000 non-null  object
#  7   Size                    15000 non-null  object
#  8   Color                   15000 non-null  object
#  9   Season                  15000 non-null  object
#  10  Review_Rating           14963 non-null  float64
#  11  Subscription_Status     15000 non-null  object
#  12  Shipping_Type           15000 non-null  object
#  13  Discount_Applied        15000 non-null  object
# ...

# %%
# Applying descriptive stats for getting a general idea 
df.describe(include="all")
# Out:
#          Customer_ID           Age Gender Item_Purchased  Category  \
# count   15000.000000  15000.000000  15000          15000     15000
# unique           NaN           NaN      2             25         4
# top              NaN           NaN   Male          Pants  Clothing
# freq             NaN           NaN  10200            734      6672
# mean     7500.500000     45.908867    NaN            NaN       NaN
# std      4330.271354     16.458889    NaN            NaN       NaN
# min         1.000000     18.000000    NaN            NaN       NaN
# 25%      3750.750000     31.000000    NaN            NaN       NaN
# 50%      7500.500000     46.000000    NaN            NaN       NaN
# 75%     11250.250000     60.000000    NaN            NaN       NaN
# max     15000.000000     75.000000    NaN            NaN       NaN
#
#         Purchase_Amount Location   Size  Color  Season  Review_Rating  \
# count      15000.000000    15000  15000  15000   15000   14963.000000
# ...

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Customer_ID                0
# Age                        0
# Gender                     0
# Item_Purchased             0
# Category                   0
# Purchase_Amount            0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review_Rating             37
# Subscription_Status        0
# Shipping_Type              0
# Discount_Applied           0
# Previous_Purchases         0
# Payment_Method             0
# Frequency_of_Purchases     0
# dtype: int64

# %%
# Filling null values with median, but category-wise, because diff category have diff medians
df['Review_Rating'] = df.groupby('Category')['Review_Rating'].transform(lambda x: x.fillna(x.median()))

# %%
# Final Check
df.isnull().sum()
# Out:
# Customer_ID               0
# Age                       0
# Gender                    0
# Item_Purchased            0
# Category                  0
# Purchase_Amount           0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review_Rating             0
# Subscription_Status       0
# Shipping_Type             0
# Discount_Applied          0
# Previous_Purchases        0
# Payment_Method            0
# Frequency_of_Purchases    0
# dtype: int64

# %%
# Converting column names into Snake-case, which make it more consistent,
# Easier to referencing and connecting with SQL and other tools.

df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
# Creating a new column 'age_group'
labels = ['Young Adult', 'Adult', 'Middle-aged', 'Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels = labels) # qcut - splits the data in n parts

# %%
# Preview
df[['age', 'age_group']].head(10)
# Out:
#    age    age_group
# 0   43        Adult
# 1   63       Senior
# 2   30  Young Adult
# 3   24  Young Adult
# 4   33        Adult
# 5   73       Senior
# 6   54  Middle-aged
# 7   37        Adult
# 8   22  Young Adult
# 9   25  Young Adult

# %%
# Checking age_group distribution
df['age_group'].value_counts()
# Out:
# age_group
# Adult          3917
# Young Adult    3754
# Middle-aged    3709
# Senior         3620
# Name: count, dtype: int64

# %%
# Creating a new column 'purchase_frequency_days', by mapping frequency_of_purchases with this dict
frequency_dict = {
    'Fortnightly': 14, 
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90, 
    'Bi-Weekly': 14, 
    'Annually': 365, 
    'Every 3 Months' : 90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_dict)

# %%
# Preview
df[['purchase_frequency_days', 'frequency_of_purchases']].head(10)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                      365               Annually
# 2                       90              Quarterly
# 3                      365               Annually
# 4                        7                 Weekly
# 5                       14            Fortnightly
# 6                       90              Quarterly
# 7                       90              Quarterly
# 8                        7                 Weekly
# 9                       90         Every 3 Months

# %%
# Checking for duplicate rows
print(f"Duplicate rows: {df.duplicated().sum()}")
df = df.drop_duplicates()
# Out:
# Duplicate rows: 0

# %%
# Checking for outliers in numeric columns
numeric_cols = ['age', 'purchase_amount', 'previous_purchases', 'review_rating']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# age: 0 outliers
# purchase_amount: 0 outliers
# previous_purchases: 0 outliers
# review_rating: 0 outliers

# %%
# Connecting to MySQL
from sqlalchemy import create_engine

username = "pyuser"
password = "py_password"
host = "localhost"
port = "3306"
database = "customer_behaviour"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

# Loading Dataframe into MySQL
table_name = "customer_purchases"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 16
#      14 # Loading Dataframe into MySQL
#      15 table_name = "customer_purchases"
# ---> 16 df.to_sql(table_name, engine, if_exists="replace", index=False)
#      18 print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
#
# NameError: name 'df' is not defined
